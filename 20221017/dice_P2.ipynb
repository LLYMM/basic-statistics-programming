# %%
S = {1,2,3,4,5,6}
print(len(S))
A  = {2,4,6}
B = {5,6}
# Out:
# 6

# %%
def n(event):
  return len(event)

# %%
n(S)
# Out:
# 6

# %%
P = n(A)/n(S)

# %%
print(P)
# Out:
# 0.5

# %%
C = {1,2}
D = {5,6}

# %%
CD = {  }
