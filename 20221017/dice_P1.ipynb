# %%
import math

# %%
def combination_count(n, r):
    return math.factorial(n) // math.factorial(n - r) * math.factorial(r)

print(combination_count(7, 3))
# Out:
# 1260

# %%
S = combination_count(7,3)
A = combination_count(4,2) * combination_count(3,1)
P = A/S
print(P)
# Out:
# 0.05714285714285714
