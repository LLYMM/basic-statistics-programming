# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x = [1,  2, 3,  4, 5,  6, 7,  8, 9]
y = [10, 40, 30, 50, 5, 10, 60, 100, 200]

# %%
plt.xlabel('X data')
plt.ylabel('Y data')

plt.grid(color = 'green', alpha = 0.5, linestyle = '--')
plt.plot(x, y)

# %%
y = [10 , np.nan, 30, 50, 60, 10, 60, 100, 200]
plt.grid(color='green', alpha = 0.5, linestyle = '--')
plt.plot(x, y, marker='o')

# %%
#결측치 처리 함수
def missing_data(y1, y2):
  avg_data = (y2+y1)/2
  return avg_data

# %%
y[1] = missing_data(y[0], y[2])
plt.grid(color='green', alpha = 0.5, linestyle = '--')
plt.plot(x, y, marker='o')

# %%
def map1(x1,y1,x3,y3,x2):

  a= (y3-y1)/(x3-x1)
  b= y1-a*x1
  estimated_data = a * x2 + b
  return estimated_data

# %%
y[1] = map1(x[0],y[0],x[2], y[2], x[1])
plt.grid(color='green', alpha = 0.5, linestyle = '--')
plt.plot(x, y, marker='o')

# %%
y = [10, 40, 30, 50, 5, 10, 60, 100, 200]
x = [1,  2,3,  4,5,  6,7,  8,9]

#1.3일때 데이터 추정
y[1] = map1(x[0],y[0],x[2], y[2], 1.3)
plt.grid(color='green', alpha = 0.5, linestyle = '--')
plt.plot(x, y, marker='o')

# %%
def map1(x2, y1, x2, y2, x_input):
  d1 = 
  d2 =
  alpha = 
  beta = 

  estimeted_data = alpha * y1 + beta*y2
  return estimated_data

# %%
Y = [[2,3],
     [4,0]]

X = [[0,1],
     [0,1]]

# %%
def map_2D(x1, y1, x2, z2, y2, x3, y3, z3, x4, y4, z4, x_input, y_input):
  h2 = (y_input - y1)/(y3-y1)
  h1 = (y2 - y_input)/(y2-y1)
  M = h2 * z2 + h1 + z1
  
  print("h1: " ,h1)
  print("h2: " ,h2)
  print("m: ", M)
  
  h3 = (y_input - y3)/(y4-y3)
  h4 = (y4 - y_input)/(y4-y3)
  N = h4 * z3 + h3 + z4
  
  print("h3: " ,h3)
  print("h4: " ,h4)
  print("N: ", N)

  w1 = (x_input - x1)/(x3-x1)
  w2 = (x3 - x_input)/(x3-x1)
  P = M*w2 + N + w1

  return P

# %%
result = map_2D(0, 0, 2, 0,1,4, 1,0,3, 1,1,0, 0,0)
#print(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-114-1a30989febc2> in <module>
# ----> 1 result = map_2D(0, 0, 2, 0,1,4, 1,0,3, 1,1,0, 0,0)
#       2 #print(result)
#
# TypeError: map_2D() takes 13 positional arguments but 14 were given
