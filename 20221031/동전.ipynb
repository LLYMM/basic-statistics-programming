# %%
import math

# %%
def combination_count(n, r):
    return math.factorial(n) // (math.factorial(n -r) * math.factorial(r))

# %%
print(combination_count(4, 0))
# Out:
# 1

# %%
def permutation_with_repetition_count(n,r):
    return math.pow(n, r)
 print(combination_with_repetition_count(n, r))
# Out:
#   File "<tokenize>", line 3
#     print(combination_with_repetition_count(n, r))
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
print(combination)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f783e85b454b> in <module>
# ----> 1 print(combination)
#
# NameError: name 'combination' is not defined

# %%
print("")

# %%
print("n을 입력하세요")
n = input()
if n > 4 :
  print("다시 입력하세요")
  n = int(input())

# %%
P = combination_count(4, int(n))/(2*2*2)
print(P)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c020a3926217> in <module>
# ----> 1 P = combination_count(4, int(n))/(2*2*2)
#       2 print(P)
#
# NameError: name 'combination_count' is not defined
