# %%
import sys
print(sys.version )
# Out:
# 3.7.15 (default, Oct 12 2022, 19:14:55)
# [GCC 7.5.0]

# %%
# !python --version
# Out:
# Python 3.7.15

# %%
import math

# %%
def permutations_count(n, r):
    return math.factorial(n) // math.factorial(n - r)

print(permutations_count(4, 2))
# Out:
# 12

# %%
def combination_count(n, r):
    return math.factorial(n) // (math.factorial(n - r) * math.factorial(r))

print(combination_count(4, 2))
# Out:
# 6

# %%
print("빨간공 r개 파란공  b개가 들어있는 주머니에서  n개의 공을 꺼내려고 합니다.")
print("뽑힌 공 중 파란공의 개수를 확률 변수 X라고 했을 때 확률 분포를 나타내시오")
# Out:
# 빨간공 r개 파란공  b개가 들어있는 주머니에서  n개의 공을 꺼내려고 합니다.
# 뽑힌 공 중 파란공의 개수를 확률 변수 X라고 했을 때 확률 분포를 나타내시오

# %%
b=0
r=0
n=0
X=0.0
print("빨간공의 개수를 입력하시오")
test = input()
r = int(test)
print("파란공의 개수를 입력하세요")
test = input()
b = int(test)

print("파란공의 개수를 입력하세요")
test = input()
n = int(test)
sum = 0
avg = 0
for i in range(n+1):
  result = combination_count(r,n-1) * (combination_count(b,i) / combination_count(b+r,n))
  sum += result
  avg += result*i
  print("P(",i,") = ", result)
print("Psum = ", sum)
print("avg = ", avg)

for i in range(n+1):
  result = combination_count(r,n-1) * (combination_count(b,i) / combination_count(b+r,n))
  var += (i - avg) * (i - avg) * result

print("var = ", var)
# Out:
# 빨간공의 개수를 입력하시오
# 3
# 파란공의 개수를 입력하세요
# 4
# 파란공의 개수를 입력하세요
# 5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-6b651db268ee> in <module>
#      16 avg = 0
#      17 for i in range(n+1):
# ---> 18   result = combination_count(r,n-1) * (combination_count(b,i) / combination_count(b+r,n))
#      19   sum += result
#      20   avg += result*i
#
# <ipython-input-40-b18aa1e57857> in combination_count(n, r)
#       1 def combination_count(n, r):
# ----> 2     return math.factorial(n) // (math.factorial(n - r) * math.factorial(r))
#       3
#       4 print(combination_count(4, 2))
#
# ValueError: factorial() not defined for negative values

# %%
sum = 0
avg = 0
var = 0
for i in range(n+1):
  result = combination_count(r,n-1) * (combination_count(b,i) / combination_count(b+r,n))
  sum += result
  avg += result*i

  print("P(",i,") = ", result)
print("Psum = ", sum)
print("avg = ", avg)

for i in range(n+1):
  result = combination_count(r,n-1) * (combination_count(b,i) / combination_count(b+r,n))
  var += (i - avg) * (i - avg) * result

print("var = ", var)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-8d363ef7a0ba> in <module>
#       3 var = 0
#       4 for i in range(n+1):
# ----> 5   result = combination_count(r,n-1) * (combination_count(b,i) / combination_count(b+r,n))
#       6   sum += result
#       7   avg += result*i
#
# <ipython-input-40-b18aa1e57857> in combination_count(n, r)
#       1 def combination_count(n, r):
# ----> 2     return math.factorial(n) // (math.factorial(n - r) * math.factorial(r))
#       3
#       4 print(combination_count(4, 2))
#
# ValueError: factorial() not defined for negative values

# %%
def combination_count(n, r):
    return math.factorial(n) // (math.factorial(n - r) * math.factorial(r))

print(combination_count(4, 2))
